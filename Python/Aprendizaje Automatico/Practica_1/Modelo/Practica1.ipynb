# %% [markdown]
# ### Importación de librerias

# %%
import pandas as pd
from sklearn import linear_model

# %% [markdown]
# ### Exploración de datos

# %%
direccion = "../Dataset"
X = pd.read_csv(direccion + "/trainX_reto1.csv", sep=";")
Y = pd.read_csv(direccion + "/trainY_reto1.csv", sep=";")
X_ordered = X.sort_values(by="Unnamed: 0", ascending=True)
X_ordered
# Out:
#      Unnamed: 0   age    bp     sg   al   su     rbc        pc         pcc  \
# 121           0  48.0  80.0   1.02  1.0  0.0       ?    normal  notpresent
# 287           1   7.0  50.0   1.02  4.0  0.0       ?    normal  notpresent
# 82            2  62.0  80.0   1.01  2.0  3.0  normal    normal  notpresent
# 112           3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 33            4  51.0  80.0   1.01  2.0  0.0  normal    normal  notpresent
# ..          ...   ...   ...    ...  ...  ...     ...       ...         ...
# 240         395  55.0  80.0   1.02  0.0  0.0  normal    normal  notpresent
# 18          396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 211         397  12.0  80.0   1.02  0.0  0.0  normal    normal  notpresent
# 50          398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 94          399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
# ...
